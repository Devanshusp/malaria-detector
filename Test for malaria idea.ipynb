# %%
import cv2              #Import the OpenCV Library
import numpy as np      #Import the Numpy library

# %%
infected = cv2.imread("trial data/C100P61ThinF_IMG_20150918_144104_cell_162.png")   #Load the image file into memory
cv2.imshow("Infected cell", infected)                  #Display that image

cv2.waitKey(0)                            #Cleanup after any key is pressed
cv2.destroyAllWindows()

# %%
def averagecolor(image):
    return np.mean(image, axis=(0, 1))

# %%
print (averagecolor(infected))
# Out:
# [118.90131329 118.61624477 162.95793681]
